# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Gender Inequality Index.csv")

# %%
df.head(5)
# Out:
#   ISO3               Country Continent           Hemisphere  \
# 0  AFG           Afghanistan      Asia  Northern Hemisphere
# 1  AGO                Angola    Africa  Southern Hemisphere
# 2  ALB               Albania    Europe  Northern Hemisphere
# 3  AND               Andorra    Europe  Northern Hemisphere
# 4  ARE  United Arab Emirates      Asia  Northern Hemisphere
#
#   Human Development Groups UNDP Developing Regions  HDI Rank (2021)  \
# 0                      Low                      SA            180.0
# 1                   Medium                     SSA            148.0
# 2                     High                     ECA             67.0
# 3                Very High                     NaN             40.0
# 4                Very High                      AS             26.0
#
#    GII Rank (2021)  Gender Inequality Index (1990)  \
# 0            167.0                             NaN
# 1            136.0                           0.725
# ...

# %%
df.tail(5)
# Out:
#     ISO3       Country Continent           Hemisphere  \
# 190  WSM         Samoa   Oceania  Southern Hemisphere
# 191  YEM         Yemen      Asia  Northern Hemisphere
# 192  ZAF  South Africa    Africa  Southern Hemisphere
# 193  ZMB        Zambia    Africa  Southern Hemisphere
# 194  ZWE      Zimbabwe    Africa  Southern Hemisphere
#
#     Human Development Groups UNDP Developing Regions  HDI Rank (2021)  \
# 190                     High                     EAP            111.0
# 191                      Low                      AS            183.0
# 192                     High                     SSA            109.0
# 193                   Medium                     SSA            154.0
# 194                   Medium                     SSA            146.0
#
#      GII Rank (2021)  Gender Inequality Index (1990)  \
# 190             99.0                             NaN
# 191            170.0                             NaN
# ...

# %%
df.isnull().sum()
# Out:
# ISO3                               0
# Country                            0
# Continent                          0
# Hemisphere                         0
# Human Development Groups           4
# UNDP Developing Regions           44
# HDI Rank (2021)                    4
# GII Rank (2021)                   25
# Gender Inequality Index (1990)    67
# Gender Inequality Index (1991)    67
# Gender Inequality Index (1992)    67
# Gender Inequality Index (1993)    67
# Gender Inequality Index (1994)    67
# Gender Inequality Index (1995)    65
# Gender Inequality Index (1996)    65
# Gender Inequality Index (1997)    65
# Gender Inequality Index (1998)    59
# Gender Inequality Index (1999)    54
# Gender Inequality Index (2000)    51
# Gender Inequality Index (2001)    46
# Gender Inequality Index (2002)    45
# Gender Inequality Index (2003)    42
# Gender Inequality Index (2004)    39
# Gender Inequality Index (2005)    36
# Gender Inequality Index (2006)    33
# ...

# %%
df.isnull().sum().sum()
# Out:
# 1428

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 40 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0
# Gender Inequality Index (2001)    46
# Gender Inequality Index (2002)    45
# Gender Inequality Index (2003)    42
# Gender Inequality Index (2004)    39
# Gender Inequality Index (2005)    36
# Gender Inequality Index (2006)    33
# Gender Inequality Index (2007)    32
# Gender Inequality Index (2008)    32
# Gender Inequality Index (2009)    32
# Gender Inequality Index (2010)    30
# Gender Inequality Index (2011)    28
# Gender Inequality Index (2012)    28
# Gender Inequality Index (2013)    28
# Gender Inequality Index (2014)    28
# ...

# %%
hg=['Human Development Groups','UNDP Developing Regions']
hg_values=df[hg].sum()
hg_values
# Out:
# Human Development Groups     4
# UNDP Developing Regions     44
# dtype: int64

# %%
land=['ISO3','Country','Continent','Hemisphere']
land_values=df[land].sum()
land_values
# Out:
# ISO3          AFGAGOALBANDAREARGARMATGAUSAUTAZEBDIBELBENBFAB...
# Country       AfghanistanAngolaAlbaniaAndorraUnited Arab Emi...
# Continent     AsiaAfricaEuropeEuropeAsiaAmericaAsiaAmericaOc...
# Hemisphere    Northern HemisphereSouthern HemisphereNorthern...
# dtype: object

# %%
fig, ax = plt.subplots(figsize=(10, 6))
gii_values.sort_values().plot(kind='barh')
ax.set_title('Gender Inequality Index')
ax.set_xlabel('Ranges')
ax.set_ylabel('Years')
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
hg_values.plot(kind='pie', autopct='%1.1f%%')
ax.set_title('Developing groups or areas')
ax.set_ylabel('')  
plt.tight_layout()
plt.show()

# %%
colnames=df.select_dtypes(["object"]).columns
colnames
# Out:
# Index(['ISO3', 'Country', 'Continent', 'Hemisphere'], dtype='object')

# %%
from sklearn.preprocessing import OrdinalEncoder
le=OrdinalEncoder()
df[colnames]=le.fit_transform(df[colnames])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 194
# Data columns (total 40 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ISO3                            195 non-null    float64
#  1   Country                         195 non-null    float64
#  2   Continent                       195 non-null    float64
#  3   Hemisphere                      195 non-null    float64
#  4   Human Development Groups        195 non-null    int32
#  5   UNDP Developing Regions         195 non-null    int32
#  6   HDI Rank (2021)                 195 non-null    int32
#  7   GII Rank (2021)                 195 non-null    int32
#  8   Gender Inequality Index (1990)  195 non-null    int32
#  9   Gender Inequality Index (1991)  195 non-null    int32
#  10  Gender Inequality Index (1992)  195 non-null    int32
#  11  Gender Inequality Index (1993)  195 non-null    int32
# ...

# %%
colname=df.select_dtypes(["int64","float64"]).columns
colname
# Out:
# Index(['ISO3', 'Country', 'Continent', 'Hemisphere'], dtype='object')

# %%
from scipy.stats import skew
for cols in df[colname]:
    print(cols)
    print(skew(df[cols]))
    
    
    plt.figure()
    sns.distplot(df[cols])
    plt.show()
# Out:
# ISO3
# 0.0
# Country
# 0.0
# Continent
# 0.1345965631069862
# Hemisphere
# 1.4999999999999998
